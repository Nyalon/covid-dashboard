# %%
api_key = 'IPMODP97MJ95M4PO'

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
import time
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
cases = pd.read_csv('https://covid.ourworldindata.org/data/ecdc/total_cases.csv')
usa_date = pd.DataFrame({"Date": cases["date"], "World": cases["World"], "USA": cases["United States"]})
usa_date['Date'] = usa_date.Date.astype(str)
w = 0
stock_list = ['ba', 'zm', 'ccl', 'goog', 'dji']
def new_stock(stock_sym):
    ts = TimeSeries(key=api_key, output_format='pandas')
    ti = TechIndicators(key=api_key, output_format='pandas')
    stock_sym2, meta_data = ts.get_daily(symbol=stock_sym, outputsize = 'full')
    stock_sym3 = pd.DataFrame({"Date": stock_sym2.index, eval("stock_sym"): stock_sym2["4. close"], eval("stock_sym") + "_Volume": stock_sym2["5. volume"] })
    stock_sym3.reset_index(drop=True, inplace=True)
    stock_sym3['Date'] = stock_sym3.Date.astype(str)
    return(stock_sym3)

for x in stock_list:
    w += 1
    print(w)
    if w == 1:
        first_frame = new_stock(x)
        time.sleep(10)
        print(first_frame)
    elif w == 2:
        all_frames = new_stock(x)
        fff = all_frames.merge(first_frame, left_on='Date', right_on='Date')
        print(fff)
        print("dig")
        time.sleep(10)
    elif w == 3:
        all_frames = new_stock(x)
        ggg = all_frames.merge(fff, left_on='Date', right_on='Date')
        print(ggg)
        time.sleep(10)
    elif w == 4:
        all_frames = new_stock(x)
        hhh = all_frames.merge(ggg, left_on='Date', right_on='Date')
        time.sleep(10)
    else:
        all_frames = new_stock(x)
        iii = all_frames.merge(hhh, left_on='Date', right_on='Date')
        jjj = iii.merge(usa_date, left_on='Date', right_on='Date')
        print(jjj)
        jjj.to_csv('dow_data.csv')
# Out:
# 1
#             Date      ba   ba_Volume
# 0     2020-04-16  134.24  40110412.0
# 1     2020-04-15  145.98  39170590.0
# 2     2020-04-14  141.00  33796548.0
# 3     2020-04-13  147.33  25944952.0
# 4     2020-04-09  151.84  37869667.0
# ...          ...     ...         ...
# 5026  2000-04-24   37.88  10279700.0
# 5027  2000-04-20   40.06   8110700.0
# 5028  2000-04-19   37.25   5749000.0
# 5029  2000-04-18   34.75   3379100.0
# 5030  2000-04-17   35.31   3761600.0
#
# [5031 rows x 3 columns]
# 2
#            Date      zm   zm_Volume      ba   ba_Volume
# 0    2020-04-16  150.26  14602634.0  134.24  40110412.0
# 1    2020-04-15  151.56  14193277.0  145.98  39170590.0
# 2    2020-04-14  141.89  11679919.0  141.00  33796548.0
# 3    2020-04-13  135.92  15411680.0  147.33  25944952.0
# 4    2020-04-09  124.51  15512973.0  151.84  37869667.0
# ..          ...     ...         ...     ...         ...
# 246  2019-04-25   65.00   3863275.0  382.80   6614992.0
# 247  2019-04-24   63.20   4973529.0  375.46   9855141.0
# 248  2019-04-23   69.00   6786513.0  374.02   4894517.0
# 249  2019-04-22   65.70   9949738.0  375.17   4147652.0
# 250  2019-04-18   62.00  25764659.0  380.07   4703105.0
#
